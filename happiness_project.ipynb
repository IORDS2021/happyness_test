# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
wh_all_df = pd.read_excel('WHR21.xls')
wh_all_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
wh_all_df = pd.read_excel('WHR21.xls')
wh_all_df
# Out:
#         Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0          Australia  2005     7.340688           10.570512        0.967892
# 1            Belgium  2005     7.262290           10.591697        0.934875
# 2             Brazil  2005     6.636771            9.421541        0.882923
# 3             Canada  2005     7.418048           10.609852        0.961552
# 4     Czech Republic  2005     6.439257           10.157401        0.918759
# ...              ...   ...          ...                 ...             ...
# 1992       Venezuela  2020     4.892200            9.073104        0.860927
# 1993         Vietnam  2020     5.410800            8.973157        0.849987
# 1994           Yemen  2020     3.657900            7.578437        0.831537
# 1995          Zambia  2020     4.073400            8.145451        0.707518
# 1996        Zimbabwe  2020     3.144800            7.942595        0.750470
#
# ...

# %%
cols_of_interest = wh_all_df.columns[1:9]

# %%
wh_withna_df = wh_all_df[cols_of_interest]
wh_withna_df
# Out:
#       year  Life Ladder  Log GDP per capita  Social support  \
# 0     2005     7.340688           10.570512        0.967892
# 1     2005     7.262290           10.591697        0.934875
# 2     2005     6.636771            9.421541        0.882923
# 3     2005     7.418048           10.609852        0.961552
# 4     2005     6.439257           10.157401        0.918759
# ...    ...          ...                 ...             ...
# 1992  2020     4.892200            9.073104        0.860927
# 1993  2020     5.410800            8.973157        0.849987
# 1994  2020     3.657900            7.578437        0.831537
# 1995  2020     4.073400            8.145451        0.707518
# 1996  2020     3.144800            7.942595        0.750470
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            71.400002                      0.934973
# 1                            69.900002                      0.923843
# ...

# %%
wh_withna_df = wh_all_df[cols_of_interest]
wh_withna_df
# Out:
#       year  Life Ladder  Log GDP per capita  Social support  \
# 0     2008     3.723590            7.144916        0.450662
# 1     2009     4.401778            7.314788        0.552308
# 2     2010     4.758381            7.421525        0.539075
# 3     2011     3.831719            7.394349        0.521104
# 4     2012     3.782938            7.480296        0.520637
# ...    ...          ...                 ...             ...
# 1843  2015     3.703191            7.827643        0.735800
# 1844  2016     3.735400            7.819675        0.768425
# 1845  2017     3.638300            7.851042        0.754147
# 1846  2018     3.616480            7.896704        0.775388
# 1847  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                            50.799999                      0.718114
# 1                            51.200001                      0.678896
# ...

# %%
sns.pairplot(wh_withna_df)

# %%
sns.pairplot(wh_withna_df)

# %%
wh_withna_df.isna().sum()
# Out:
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   29
# Social support                       13
# Healthy life expectancy at birth     52
# Freedom to make life choices         31
# Generosity                           83
# Perceptions of corruption           103
# dtype: int64

# %%
wh_withna_df.isna().sum()
# Out:
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   29
# Social support                       13
# Healthy life expectancy at birth     52
# Freedom to make life choices         31
# Generosity                           83
# Perceptions of corruption           103
# dtype: int64

# %%
wh_withna_df.shape
# Out:
# (1997, 8)

# %%
wh_df = wh_withna_df.dropna()

# %%
wh_df.shape
# Out:
# (1776, 8)

# %%
print(f"We lost {np.round((wh_withna_df.shape[0]-wh_df.shape[0])/wh_withna_df.shape[0]*100, 2)}% data")
# Out:
# We lost 11.07% data

# %%
wh_corrmat = wh_df.corr()
wh_corrmat
sns.heatmap(wh_corrmat)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(wh_corrmat, cmap='coolwarm', vmin=-1, vmax=1, annot=True);

# %%
sns.heatmap(wh_corrmat, cmap='coolwarm', vmin=-1, vmax=1, annot=True);

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import happypred

# %%
X_train_path, y_train_path, X_test_path, y_test_path = happypred.whdata_to_csv("WHR21.xls")
